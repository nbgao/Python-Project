# %% [markdown]
# # 1. 数据清洗及可视化

# %% [markdown]
# ## 数据清洗
# ### 1. 检查数据

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

data = pd.read_csv('./train.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d334b7492345> in <module>()
#       4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 6 mpl.rcParams['font.sans-serif'] = ['SimHei']
#       7
#       8 data = pd.read_csv('./train.csv')
#
# NameError: name 'mpl' is not defined

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
len(data)
# Out:
# 891

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### 查看特征类别分布平衡

# %%
sns.countplot(x='Survived', data=data)

# %%
data.drop(['PassengerId','Name'], axis=1, inplace=True)
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %% [markdown]
# ### 2. 相关系数

# %%
g = sns.heatmap(data[['Survived', 'SibSp', 'Parch', 'Age', 'Fare', 'Pclass']].corr(),
                cmap='Blues', annot=True)

# %% [markdown]
# ### 3. 缺失值

# %%
Age0 = data[(data['Survived']==0) & (data['Age'].notnull())]['Age']
Age1 = data[(data['Survived']==1) & (data['Age'].notnull())]['Age']

g = sns.kdeplot(Age0, legend=True, shade=True, color='g', label='NotSurvived')
g = sns.kdeplot(Age1, legend=True, shade=True, color='b', label='Survived')

# %%
g = sns.factorplot(x='Sex', y='Age', data=data, kind='box')
g = sns.factorplot(x='Pclass', y='Age', data=data, kind='box')

# %%
index = list(data[data['Age'].isnull()].index)
Age_mean = np.mean(data[data['Age'].notnull()]['Age'])
copy_data = data.copy()
for i in index:
    filling_age = np.mean(copy_data[(copy_data['Pclass'] == copy_data.iloc[i]['Pclass'])
                                   & (copy_data['SibSp'] == copy_data.iloc[i]['SibSp']) 
                                   & (copy_data['Parch'] == copy_data.iloc[i]['Parch'])
                                   ]['Age'])
    if not np.isnan(filling_age):
        data['Age'].iloc[i] = filling_age
    else:
        data['Age'].iloc[i] = Age_mean
        
g = sns.kdeplot(Age0, legend=True, shade=True, color='g', label='NotSurvived')
g = sns.kdeplot(Age1, legend=True, shade=True, color='b', label='Survived')

# %%
data[data['Cabin'].notnull()]['Cabin'].head(10)
# Out:
# 1             C85
# 3            C123
# 6             E46
# 10             G6
# 11           C103
# 21            D56
# 23             A6
# 27    C23 C25 C27
# 31            B78
# 52            D33
# Name: Cabin, dtype: object

# %%
data['Cabin'].fillna('U', inplace=True)
data['Cabin'] = data['Cabin'].map(lambda i: list(i)[0])

g = sns.factorplot(x='Cabin', y='Survived', data=data, ci=False, kind='bar',
                   order=['A','B','C','D','E','F','T','U'])

# %%
g = sns.countplot(x='Cabin', hue='Pclass', data=data, order=['A','B','C','D','F','T','U'])

# %% [markdown]
# ### 偏态分布

# %%
g = sns.kdeplot(data[data['Survived']==0]['Fare'], shade='True', label='NotSurvived', color='g')
g = sns.kdeplot(data[data['Survived']==1]['Fare'], shade='True', label='Survived', color='b')

# %%
data['Fare'] = data['Fare'].map(lambda i: np.log(i) if i>0 else 0)
g = sns.distplot(data['Fare'])
print('Skew Coefficient:%.2f' % (data['Fare'].skew()))
# Out:
# Skew Coefficient:0.44

# %% [markdown]
# ### 5. 数值化和标准化

# %%
import re
r = re.compile(r'\w*') #正则表达式，查找所有单词字符[a-z/A-Z/0-9]

Ticket = []
for i in data['Ticket']:
    sp = i.split(' ')
    if len(sp)==1:
        Ticket.append('U')
    else:
        t = r.findall(sp[0]) # 查找所有单词字符，忽略符号，返回列表
        Ticket.append(''.join(t)) # 将t中所有字符串合并
data['Ticket'] = Ticket
data = pd.get_dummies(data, columns=['Ticket'], prefix='T')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Ticket'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ea752f416c8d> in <module>()
#       3
#       4 Ticket = []
# ----> 5 for i in data['Ticket']:
#       6     sp = i.split(' ')
#       7     if len(sp)==1:
#
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'Ticket'

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin',
#        'Embarked', 'T_U'],
#       dtype='object')

# %%
data['Sex'].replace('male', 0, inplace=True)
data['Sex'].replace('female', 1, inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch      Fare Cabin Embarked  T_U
# 0         0       3    0  22.0      1      0  1.981001     U        S    1
# 1         1       1    1  38.0      1      0  4.266662     C        C    1
# 2         1       3    1  26.0      0      0  2.070022     U        S    1
# 3         1       1    1  35.0      1      0  3.972177     C        S    1
# 4         0       3    0  35.0      0      0  2.085672     U        S    1

# %%
from collections import Counter

def outlier_detect(n, df, features):#定义函数 outlier_detect 探测离群点，输入变量 n, df, features，返回 outlier
    outlier_index = []
    for feature in features:
        Q1 = np.percentile(df[feature], 25)#计算上四分位数（1/4）
        Q3 = np.percentile(df[feature], 75)#计算下四分位数（3/4）
        IQR = Q3 - Q1
        outlier_span = 1.5 * IQR
        col = ((data[data[feature] > Q3 + outlier_span]) |
               (data[data[feature] < Q1 - outlier_span])).index
        outlier_index.extend(col)
        print('%s: %f (Q3+1.5*IQR) , %f (Q1-1.5*QIR) )' %
              (feature, Q3 + outlier_span, Q1 - outlier_span))
    outlier_index = Counter(outlier_index)#计数
    outlier = list(i for i, j in outlier_index.items() if j >= n)
    print('number of outliers: %d' % len(outlier))
    print(df[['Age', 'Parch', 'SibSp', 'Fare']].loc[outlier])
    return outlier

outlier = outlier_detect(3, data, ['Age', 'Parch', 'SibSp', 'Fare'])#调用函数 outlier_detect
# Out:
# Age: 59.500000 (Q3+1.5*IQR) , -0.500000 (Q1-1.5*QIR) )
# Parch: 0.000000 (Q3+1.5*IQR) , 0.000000 (Q1-1.5*QIR) )
# SibSp: 2.500000 (Q3+1.5*IQR) , -1.500000 (Q1-1.5*QIR) )
# Fare: 5.482703 (Q3+1.5*IQR) , 0.019461 (Q1-1.5*QIR) )
# number of outliers: 4
#       Age  Parch  SibSp      Fare
# 438  64.0      4      1  5.572154
# 27   19.0      2      3  5.572154
# 88   23.0      2      3  5.572154
# 341  24.0      2      3  5.572154
