# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Series

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# # 2. DataFrame

# %%
dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns = list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.722588 -0.135287 -0.228525  0.710964
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254
# 2013-01-06 -1.226616  0.421710  0.843545  0.912847

# %%
df2 = pd.DataFrame({'A':1,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3]*4, dtype='int32'),
                    'E': pd.Categorical(["test","train","test","train"]),
                    'F': 'foo'})
df2
# Out:
#    A          B    C  D      E    F
# 0  1 2013-01-02  1.0  3   test  foo
# 1  1 2013-01-02  1.0  3  train  foo
# 2  1 2013-01-02  1.0  3   test  foo
# 3  1 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # 2. Data watch

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.722588 -0.135287 -0.228525  0.710964
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254
# 2013-01-06 -1.226616  0.421710  0.843545  0.912847

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.72258785, -0.13528736, -0.22852527,  0.71096392],
#        [-0.64921574,  1.01789772, -0.62756704,  0.49684195],
#        [-0.43763846,  0.83999274, -1.16571207,  0.25932035],
#        [-0.60862824, -1.25636761, -0.56508782,  1.73411787],
#        [-0.55604999,  0.03472299,  2.03619459, -1.48025412],
#        [-1.22661646,  0.42171018,  0.84354484,  0.91284706]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.866789  0.153778  0.048808  0.438973
# std    0.501315  0.821660  1.180478  1.067239
# min   -1.722588 -1.256368 -1.165712 -1.480254
# 25%   -1.082266 -0.092785 -0.611947  0.318701
# 50%   -0.628922  0.228217 -0.396807  0.603903
# 75%   -0.569195  0.735422  0.575527  0.862376
# max   -0.437638  1.017898  2.036195  1.734118

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.722588   -0.649216   -0.437638   -0.608628   -0.556050   -1.226616
# B   -0.135287    1.017898    0.839993   -1.256368    0.034723    0.421710
# C   -0.228525   -0.627567   -1.165712   -0.565088    2.036195    0.843545
# D    0.710964    0.496842    0.259320    1.734118   -1.480254    0.912847

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.710964 -0.228525 -0.135287 -1.722588
# 2013-01-02  0.496842 -0.627567  1.017898 -0.649216
# 2013-01-03  0.259320 -1.165712  0.839993 -0.437638
# 2013-01-04  1.734118 -0.565088 -1.256368 -0.608628
# 2013-01-05 -1.480254  2.036195  0.034723 -0.556050
# 2013-01-06  0.912847  0.843545  0.421710 -1.226616

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06 -1.226616  0.421710  0.843545  0.912847
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842
# 2013-01-01 -1.722588 -0.135287 -0.228525  0.710964

# %%
df.sort_index(by='B')
# Out:
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#                    A         B         C         D
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118
# 2013-01-01 -1.722588 -0.135287 -0.228525  0.710964
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254
# 2013-01-06 -1.226616  0.421710  0.843545  0.912847
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842

# %% [markdown]
# # 4. Choose & Split

# %%
df['A']
# Out:
# 2013-01-01   -1.722588
# 2013-01-02   -0.649216
# 2013-01-03   -0.437638
# 2013-01-04   -0.608628
# 2013-01-05   -0.556050
# 2013-01-06   -1.226616
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.722588 -0.135287 -0.228525  0.710964
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118

# %% [markdown]
# ## Choose by labels

# %%
df.loc[dates[0]]
# Out:
# A   -1.722588
# B   -0.135287
# C   -0.228525
# D    0.710964
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01 -1.722588 -0.135287
# 2013-01-02 -0.649216  1.017898
# 2013-01-03 -0.437638  0.839993
# 2013-01-04 -0.608628 -1.256368
# 2013-01-05 -0.556050  0.034723
# 2013-01-06 -1.226616  0.421710

# %%
df.loc[dates[0], 'A']
# Out:
# -1.7225878534603216

# %%
df.at[dates[0], 'A']
# Out:
# -1.7225878534603216

# %% [markdown]
# ## Choose by position

# %%
df.iloc[3]
# Out:
# A   -0.608628
# B   -1.256368
# C   -0.565088
# D    1.734118
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.608628 -1.256368
# 2013-01-05 -0.556050  0.034723

# %%
df.iloc[[1,2,3],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.649216 -0.627567
# 2013-01-03 -0.437638 -1.165712
# 2013-01-04 -0.608628 -0.565088

# %%
df.iloc[1,1]
# Out:
# 1.0178977235414022

# %%
df.iat[1,1]
# Out:
# 1.0178977235414022

# %% [markdown]
# ## Boolean index

# %%
df[df.B > 0]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254
# 2013-01-06 -1.226616  0.421710  0.843545  0.912847

# %%
df[df > 0]
# Out:
#              A         B         C         D
# 2013-01-01 NaN       NaN       NaN  0.710964
# 2013-01-02 NaN  1.017898       NaN  0.496842
# 2013-01-03 NaN  0.839993       NaN  0.259320
# 2013-01-04 NaN       NaN       NaN  1.734118
# 2013-01-05 NaN  0.034723  2.036195       NaN
# 2013-01-06 NaN  0.421710  0.843545  0.912847

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.722588 -0.135287 -0.228525  0.710964    one
# 2013-01-02 -0.649216  1.017898 -0.627567  0.496842    one
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320    two
# 2013-01-04 -0.608628 -1.256368 -0.565088  1.734118  three
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254   four
# 2013-01-06 -1.226616  0.421710  0.843545  0.912847  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.437638  0.839993 -1.165712  0.259320   two
# 2013-01-05 -0.556050  0.034723  2.036195 -1.480254  four

# %% [markdown]
# # 5. Assignment

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df.at[dates[0], 'A'] = 0
df.iat[0, 1] = 0
df.loc[:, 'D'] = np.array([5]*len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.228525  5  NaN
# 2013-01-02 -0.649216  1.017898 -0.627567  5  1.0
# 2013-01-03 -0.437638  0.839993 -1.165712  5  2.0
# 2013-01-04 -0.608628 -1.256368 -0.565088  5  3.0
# 2013-01-05 -0.556050  0.034723  2.036195  5  4.0
# 2013-01-06 -1.226616  0.421710  0.843545  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.228525 -5  NaN
# 2013-01-02 -0.649216 -1.017898 -0.627567 -5 -1.0
# 2013-01-03 -0.437638 -0.839993 -1.165712 -5 -2.0
# 2013-01-04 -0.608628 -1.256368 -0.565088 -5 -3.0
# 2013-01-05 -0.556050 -0.034723 -2.036195 -5 -4.0
# 2013-01-06 -1.226616 -0.421710 -0.843545 -5 -5.0

# %% [markdown]
# # 6. NA items

# %%
df1 = df.reindex(index = dates[0:4], columns = list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.228525  5  NaN  1.0
# 2013-01-02 -0.649216  1.017898 -0.627567  5  1.0  1.0
# 2013-01-03 -0.437638  0.839993 -1.165712  5  2.0  NaN
# 2013-01-04 -0.608628 -1.256368 -0.565088  5  3.0  NaN

# %%
df1.dropna(how = 'any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -0.649216  1.017898 -0.627567  5  1.0  1.0

# %%
df1.fillna(value = 5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.228525  5  5.0  1.0
# 2013-01-02 -0.649216  1.017898 -0.627567  5  1.0  1.0
# 2013-01-03 -0.437638  0.839993 -1.165712  5  2.0  5.0
# 2013-01-04 -0.608628 -1.256368 -0.565088  5  3.0  5.0

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# # 6. Numerical calculas

# %% [markdown]
# ## Statistic

# %%
df.mean()
# Out:
# A   -0.579691
# B    0.176326
# C    0.048808
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.192869
# 2013-01-02    1.148223
# 2013-01-03    1.247328
# 2013-01-04    1.113983
# 2013-01-05    2.102974
# 2013-01-06    2.007728
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis = 'index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.437638 -0.160007 -2.165712  4.0  1.0
# 2013-01-04 -3.608628 -4.256368 -3.565088  2.0  0.0
# 2013-01-05 -5.556050 -4.965277 -2.963805  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ## Functions application

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.228525   5   NaN
# 2013-01-02 -0.649216  1.017898 -0.856092  10   1.0
# 2013-01-03 -1.086854  1.857890 -2.021804  15   3.0
# 2013-01-04 -1.695482  0.601523 -2.586892  20   6.0
# 2013-01-05 -2.251532  0.636246 -0.550698  25  10.0
# 2013-01-06 -3.478149  1.057956  0.292847  30  15.0

# %%
df.apply(lambda x: x.max()-x.min())
# Out:
# A    1.226616
# B    2.274265
# C    3.201907
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ## Histogram

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    6
# 1    2
# 2    6
# 3    3
# 4    5
# 5    6
# 6    2
# 7    6
# 8    2
# 9    2
# dtype: int32

# %% [markdown]
# ## Character process

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4     NaN
# 5    caba
# 6     dog
# 7     cat
# dtype: object

# %% [markdown]
# # 8. Merge

# %% [markdown]
# ## Concat

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.788962 -0.735854 -0.675995 -1.104451
# 1 -0.642836  0.709296  0.250821  1.248277
# 2 -1.013020 -1.507607 -1.090046 -0.376666
# 3 -0.677484  1.275001 -0.853859 -0.859751
# 4 -1.016372 -0.212304  0.066876 -0.054507
# 5 -1.649550  1.538028  1.384152  0.497627
# 6 -0.958320 -0.909634  0.782710 -0.387055
# 7  1.131180  0.218810  1.503299 -0.006814
# 8 -0.750368  0.516705  0.124438  0.571178
# 9 -0.616810 -2.093624  0.710415  0.862816

# %%
pieces = [df[:3], df[3:7], df[7:] ]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.788962 -0.735854 -0.675995 -1.104451
# 1 -0.642836  0.709296  0.250821  1.248277
# 2 -1.013020 -1.507607 -1.090046 -0.376666
# 3 -0.677484  1.275001 -0.853859 -0.859751
# 4 -1.016372 -0.212304  0.066876 -0.054507
# 5 -1.649550  1.538028  1.384152  0.497627
# 6 -0.958320 -0.909634  0.782710 -0.387055
# 7  1.131180  0.218810  1.503299 -0.006814
# 8 -0.750368  0.516705  0.124438  0.571178
# 9 -0.616810 -2.093624  0.710415  0.862816

# %% [markdown]
# ## Join

# %%
left = pd.DataFrame({'key': ['foo','foo'], 'lval':[1,2]})
right = pd.DataFrame({'key':['foo','foo'], 'rval':[4,5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on = 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ## Append

# %%
df = pd.DataFrame(np.random.randn(8,4), columns = ['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.322011 -1.088815  0.934268 -0.394520
# 1  0.792124 -0.102300  0.940296  0.996420
# 2 -0.218392  0.267625  0.788474  0.323868
# 3 -2.000343  0.761320  0.902657 -0.407241
# 4  0.663854 -0.165735 -0.765502 -1.227099
# 5  0.601288 -1.030018  1.028827  0.758253
# 6  0.531974  0.406295  0.616222  0.588031
# 7 -0.248760 -2.286978 -0.247745  1.213429

# %%
s = df.iloc[3]
df.append(s, ignore_index = True)
# Out:
#           A         B         C         D
# 0  0.322011 -1.088815  0.934268 -0.394520
# 1  0.792124 -0.102300  0.940296  0.996420
# 2 -0.218392  0.267625  0.788474  0.323868
# 3 -2.000343  0.761320  0.902657 -0.407241
# 4  0.663854 -0.165735 -0.765502 -1.227099
# 5  0.601288 -1.030018  1.028827  0.758253
# 6  0.531974  0.406295  0.616222  0.588031
# 7 -0.248760 -2.286978 -0.247745  1.213429
# 8 -2.000343  0.761320  0.902657 -0.407241

# %% [markdown]
# # 9. Groupby

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -1.483971  2.046891
# 1  bar    one -0.775761 -0.941647
# 2  foo    two -1.126819  1.029228
# 3  bar  three  0.694554  0.635842
# 4  foo    two  0.578319  1.732959
# 5  bar    two -2.102702  1.571594
# 6  foo    one -0.562777 -1.207829
# 7  foo  three -0.832565 -0.761529

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -2.183910  1.265789
# foo -3.427814  2.839719

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.775761 -0.941647
#     three  0.694554  0.635842
#     two   -2.102702  1.571594
# foo one   -2.046749  0.839061
#     three -0.832565 -0.761529
#     two   -0.548500  2.762187

# %% [markdown]
# ## Pivot table

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['A', 'B', 'C'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.918974 -0.194713
# 1     one  B  foo -1.550589  1.105652
# 2     two  C  foo -0.691991 -0.941114
# 3   three  A  bar  0.156805  0.819267
# 4     one  B  bar -1.070841  0.021742
# 5     one  C  bar  0.552255 -0.173932
# 6     two  A  foo  0.928721  1.681420
# 7   three  B  foo -0.408316 -1.452300
# 8     one  C  foo -0.795476 -0.478789
# 9     one  A  bar  0.359387 -0.585093
# 10    two  B  bar -0.440681  0.735903
# 11  three  C  bar  0.074301 -0.064533

# %%
pd.pivot_table(df, values = 'D', index = ['A', 'B'], columns = ['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.359387  0.918974
#       B -1.070841 -1.550589
#       C  0.552255 -0.795476
# three A  0.156805       NaN
#       B       NaN -0.408316
#       C  0.074301       NaN
# two   A       NaN  0.928721
#       B -0.440681       NaN
#       C       NaN -0.691991

# %% [markdown]
# # 10. Time Series

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min', how='sum')
# Out:
# D:\Program Soft\Anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   This is separate from the ipykernel package so we can avoid doing imports until
# 2012-01-01    22706
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.382671
# 2012-03-07   -0.395549
# 2012-03-08   -0.130475
# 2012-03-09    0.689652
# 2012-03-10    0.166416
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.382671
# 2012-03-07 00:00:00+00:00   -0.395549
# 2012-03-08 00:00:00+00:00   -0.130475
# 2012-03-09 00:00:00+00:00    0.689652
# 2012-03-10 00:00:00+00:00    0.166416
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.382671
# 2012-03-06 19:00:00-05:00   -0.395549
# 2012-03-07 19:00:00-05:00   -0.130475
# 2012-03-08 19:00:00-05:00    0.689652
# 2012-03-09 19:00:00-05:00    0.166416
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    0.841947
# 2012-02-29    1.208860
# 2012-03-31    0.251147
# 2012-04-30    0.745140
# 2012-05-31    1.641215
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    0.841947
# 2012-02    1.208860
# 2012-03    0.251147
# 2012-04    0.745140
# 2012-05    1.641215
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.841947
# 2012-02-01    1.208860
# 2012-03-01    0.251147
# 2012-04-01    0.745140
# 2012-05-01    1.641215
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts  =pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    0.555302
# 1990-06-01 09:00   -0.171260
# 1990-09-01 09:00   -1.272101
# 1990-12-01 09:00   -0.347721
# 1991-03-01 09:00    0.193180
# Freq: H, dtype: float64

# %% [markdown]
# # 11. Category

# %%
df  = pd.DataFrame({"id": [1,2,3,4,5,6], "raw_grade":['a','b','b','a','a','e']})
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values("grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # 12. Draw picture

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure()
df.plot()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# # 13. Data I/O

# %% [markdown]
# ## CSV

# %%
df.to_csv('Data/foo.csv')

# %%
pd.read_csv('Data/foo.csv')
# Out:
#      Unnamed: 0         A          B          C          D
# 0    2000-01-01  0.662886   0.368188   1.965655   1.580675
# 1    2000-01-02  0.179282  -1.791927   1.882430   2.719100
# 2    2000-01-03 -0.107847  -2.867637   0.762242   2.596619
# 3    2000-01-04 -1.858214  -2.818609   0.383060   2.847010
# 4    2000-01-05 -3.295744  -3.864909  -0.505248   2.272375
# 5    2000-01-06 -1.774508  -4.443602  -0.590307   5.130526
# 6    2000-01-07 -3.668713  -4.207482   1.191968   4.311002
# 7    2000-01-08 -3.612165  -4.629602   0.412654   3.147384
# 8    2000-01-09 -4.282029  -5.433331   1.016546   3.175593
# 9    2000-01-10 -5.493900  -5.945693   1.523440   2.205012
# 10   2000-01-11 -3.726189  -7.783836   3.213528   2.579743
# 11   2000-01-12 -3.768467  -8.249041   3.257539   2.013383
# 12   2000-01-13 -3.812678  -8.312211   1.304329   4.346987
# 13   2000-01-14 -2.270548  -8.344650   0.383077   5.680322
# 14   2000-01-15 -3.116617  -9.927604   0.688165   4.944040
# 15   2000-01-16 -2.876024  -9.610041   2.079385   5.808788
# 16   2000-01-17 -3.209205  -9.906362   0.786604   5.208485
# 17   2000-01-18 -3.452811 -10.192175   2.246516   3.544351
# 18   2000-01-19 -2.423881 -12.045096   1.792229   2.327183
# 19   2000-01-20 -1.886201 -12.920269   1.893039   2.192130
# 20   2000-01-21 -2.103327 -13.133749   2.645754   3.613304
# 21   2000-01-22 -1.518008 -13.824810   2.924521   3.744897
# 22   2000-01-23 -1.815125 -15.425853   2.618682   4.731046
# 23   2000-01-24 -1.803797 -13.880785   1.040999   3.843434
# 24   2000-01-25 -0.173896 -15.077703   0.503623   3.954878
# 25   2000-01-26  0.551919 -13.661208  -0.431554   5.646269
# 26   2000-01-27  2.761186 -12.611425  -0.635457   5.964939
